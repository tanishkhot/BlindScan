# %%
import tensorflow as tf
from tensorflow.keras import models, layers, applications
import matplotlib.pyplot as plt
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Constants
IMAGE_SIZE = 299  # Adjusted for Inception v4
BATCH_SIZE = 16
CHANNELS = 3
EPOCHS = 50

# %%
# Data Pipeline
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "/Users/tanishkhot/Coding/BlindScan/Dataset/Final_Dataset_1800",        #Chaneg it here
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
)
# Out:
# Found 1886 files belonging to 8 classes.

# %%
# Function to partition dataset remains the same
def partition_dataset(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
  if shuffle:
    ds=ds.shuffle(shuffle_size, seed = 12)

  ds_size = len(ds)
  train_size = int(train_split*ds_size)
  val_size = int(val_split*ds_size)

  train_ds = ds.take(train_size)
  val_ds = ds.skip(train_size).take(val_size)
  test_ds = ds.skip(train_size).skip(val_size)
  return train_ds, val_ds, test_ds

train_ds, val_ds, test_ds = partition_dataset(dataset)

# %%
# Data Preprocessing for Inception v4
resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Rescaling(1.0/255),  # Inception v4 expects pixel values in [-1, 1]
    layers.experimental.preprocessing.Resizing(299,299) 
])

# %%
# Prepare the datasets
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Load InceptionV4 model pre-trained on ImageNet
base_model = applications.InceptionV3(include_top=False, weights='imagenet', input_shape=(IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
base_model.trainable = False  # Freeze the base model

# %%
# Custom layers on top of Inception v4
model = models.Sequential([
    resize_and_rescale,
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu'),
    layers.Dense(8, activation='softmax')  # Assuming 8 classes for note classification
])

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
# EarlyStopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitor the validation loss
    patience=10,         # Stop if no improvement after 10 epochs
    restore_best_weights=True  # Restore model weights from the epoch with the best value of the monitored metric.
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    verbose=1
)
# Out:
# Epoch 1/50
# 94/94 [==============================] - 197s 2s/step - loss: 1.4071 - accuracy: 0.5153 - val_loss: 0.9405 - val_accuracy: 0.6761
# Epoch 2/50
# 94/94 [==============================] - 176s 2s/step - loss: 0.6599 - accuracy: 0.7976 - val_loss: 0.4981 - val_accuracy: 0.8693
# Epoch 3/50
# 94/94 [==============================] - 145s 2s/step - loss: 0.4092 - accuracy: 0.8915 - val_loss: 0.4491 - val_accuracy: 0.8750
# Epoch 4/50
# 94/94 [==============================] - 149s 2s/step - loss: 0.2881 - accuracy: 0.9354 - val_loss: 0.3540 - val_accuracy: 0.8807
# Epoch 5/50
# 94/94 [==============================] - 171s 2s/step - loss: 0.2217 - accuracy: 0.9447 - val_loss: 0.2912 - val_accuracy: 0.9205
# Epoch 6/50
# 94/94 [==============================] - 165s 2s/step - loss: 0.1513 - accuracy: 0.9754 - val_loss: 0.2106 - val_accuracy: 0.9261
# Epoch 7/50
# 94/94 [==============================] - 165s 2s/step - loss: 0.1199 - accuracy: 0.9834 - val_loss: 0.2397 - val_accuracy: 0.9091
# Epoch 8/50
# 94/94 [==============================] - 166s 2s/step - loss: 0.1031 - accuracy: 0.9820 - val_loss: 0.1673 - val_accuracy: 0.9489
# Epoch 9/50
# 94/94 [==============================] - 150s 2s/step - loss: 0.0733 - accuracy: 0.9927 - val_loss: 0.1577 - val_accuracy: 0.9489
# Epoch 10/50
# 94/94 [==============================] - 153s 2s/step - loss: 0.0681 - accuracy: 0.9860 - val_loss: 0.1380 - val_accuracy: 0.9602
# Epoch 11/50
# 94/94 [==============================] - 345s 4s/step - loss: 0.0519 - accuracy: 0.9933 - val_loss: 0.1675 - val_accuracy: 0.9375
# Epoch 12/50
# 94/94 [==============================] - 218s 2s/step - loss: 0.0384 - accuracy: 0.9980 - val_loss: 0.0948 - val_accuracy: 0.9773
# Epoch 13/50
# 94/94 [==============================] - 221s 2s/step - loss: 0.0315 - accuracy: 0.9987 - val_loss: 0.1055 - val_accuracy: 0.9716
# Epoch 14/50
# 94/94 [==============================] - 234s 2s/step - loss: 0.0258 - accuracy: 0.9993 - val_loss: 0.1072 - val_accuracy: 0.9659
# Epoch 15/50
# 94/94 [==============================] - 255s 3s/step - loss: 0.0230 - accuracy: 1.0000 - val_loss: 0.1239 - val_accuracy: 0.9716
# Epoch 16/50
# 94/94 [==============================] - 266s 3s/step - loss: 0.0180 - accuracy: 1.0000 - val_loss: 0.0798 - val_accuracy: 0.9773
# Epoch 17/50
# 94/94 [==============================] - 145s 2s/step - loss: 0.0174 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9716
# Epoch 18/50
# 94/94 [==============================] - 145s 2s/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0800 - val_accuracy: 0.9659
# Epoch 19/50
# 94/94 [==============================] - 555s 6s/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.0836 - val_accuracy: 0.9659
# Epoch 20/50
# 94/94 [==============================] - 164s 2s/step - loss: 0.0106 - accuracy: 1.0000 - val_loss: 0.1056 - val_accuracy: 0.9716
# Epoch 21/50
# 94/94 [==============================] - 172s 2s/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9659
# Epoch 22/50
# 94/94 [==============================] - 197s 2s/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9716
# Epoch 23/50
# 94/94 [==============================] - 174s 2s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9659
# Epoch 24/50
# 94/94 [==============================] - 160s 2s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0869 - val_accuracy: 0.9716
# Epoch 25/50
# 94/94 [==============================] - 150s 2s/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0709 - val_accuracy: 0.9716
# Epoch 26/50
# 94/94 [==============================] - 157s 2s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 0.9716
# Epoch 27/50
# 94/94 [==============================] - 162s 2s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9659
# Epoch 28/50
# 94/94 [==============================] - 154s 2s/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.0865 - val_accuracy: 0.9659
# Epoch 29/50
# 94/94 [==============================] - 154s 2s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.0896 - val_accuracy: 0.9716
# Epoch 30/50
# 94/94 [==============================] - 151s 2s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0810 - val_accuracy: 0.9659
# Epoch 31/50
# 94/94 [==============================] - 152s 2s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.0795 - val_accuracy: 0.9659
# Epoch 32/50
# 94/94 [==============================] - 152s 2s/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0828 - val_accuracy: 0.9716
# Epoch 33/50
# 94/94 [==============================] - 152s 2s/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0799 - val_accuracy: 0.9659
# Epoch 34/50
# 94/94 [==============================] - 151s 2s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0857 - val_accuracy: 0.9716
# Epoch 35/50
# 94/94 [==============================] - 152s 2s/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.0942 - val_accuracy: 0.9716
# Epoch 36/50
# 94/94 [==============================] - 151s 2s/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0886 - val_accuracy: 0.9659
# Epoch 37/50
# 94/94 [==============================] - 153s 2s/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0834 - val_accuracy: 0.9716
# Epoch 38/50
# 94/94 [==============================] - 153s 2s/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0831 - val_accuracy: 0.9659
# Epoch 39/50
# 94/94 [==============================] - 155s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9716
# Epoch 40/50
# 94/94 [==============================] - 152s 2s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0864 - val_accuracy: 0.9716
# Epoch 41/50
# 94/94 [==============================] - 150s 2s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0770 - val_accuracy: 0.9716
# Epoch 42/50
# 94/94 [==============================] - 149s 2s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0768 - val_accuracy: 0.9659
# Epoch 43/50
# 94/94 [==============================] - 149s 2s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9716
# Epoch 44/50
# 94/94 [==============================] - 150s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0823 - val_accuracy: 0.9716
# Epoch 45/50
# 94/94 [==============================] - 144s 2s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9716
# Epoch 46/50
# 94/94 [==============================] - 145s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0779 - val_accuracy: 0.9716
# Epoch 47/50
# 94/94 [==============================] - 160s 2s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0902 - val_accuracy: 0.9716
# Epoch 48/50
# 94/94 [==============================] - 205s 2s/step - loss: 9.8869e-04 - accuracy: 1.0000 - val_loss: 0.0853 - val_accuracy: 0.9716
# Epoch 49/50
# 94/94 [==============================] - 197s 2s/step - loss: 9.3998e-04 - accuracy: 1.0000 - val_loss: 0.0861 - val_accuracy: 0.9716
# Epoch 50/50
# 94/94 [==============================] - 181s 2s/step - loss: 8.7816e-04 - accuracy: 1.0000 - val_loss: 0.0859 - val_accuracy: 0.9716

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training And Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training And Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training And Validation Loss')

# %%
model.save('my_inceptionv4_model.h5')
model.save('my_inceptionv4_model.keras')
